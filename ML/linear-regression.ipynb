# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
import pandas as pd

data = glob.glob('/content/drive/MyDrive/DATA/fish-market/*.csv')
fish = pd.read_csv(data[0])

bream = fish.loc[fish['Species'] == 'Bream']
smelt = fish.loc[fish['Species'] == 'Smelt']

# %%
fish['Species'].unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %% [markdown]
# # Plot

# %%
import matplotlib.pyplot as plt

0

plt.scatter(bream_length, bream_weight)
plt.scatter(smelt_length, smelt_weight)

plt.xlabel('length')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
fish
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %% [markdown]
# # Process

# %%
import numpy as np

br_sm = pd.concat([bream, smelt])
fish_data = np.column_stack((br_sm['Length2'], br_sm['Weight']))
len(fish_data)
# Out:
# 49

# %%
fish_target = np.concatenate((np.ones(35), np.zeros(14)))

# %% [markdown]
# ### shuffle

# %%
from sklearn.model_selection import train_test_split

# %%
train_input, test_input, train_target, test_target = train_test_split(fish_data, fish_target, random_state=42)

# %%
 print(train_input.shape, test_input.shape)
 print(train_target.shape, test_target.shape)
# Out:
# (36, 2) (13, 2)
# (36,) (13,)
